# %%
import openai
import sys
import os
import pydub
import requests
from dotenv import load_dotenv
sys.path.append(os.path.abspath(".."))
print("All good ✅")
# Out:
# All good ✅

# %%
from src.script_generator import generate_script
from src.voice_generator import generate_voice
from src.music_handler import get_music_file
from src.audio_merger import merge_audio

# Step 1
script = generate_script("Food delivery ad")
print(script)

# Step 2
voice_path = generate_voice(script, "voice.mp3")

# Step 3 (manually downloaded music)
music_path = get_music_file("jingle.mp3")

# Step 4
final = merge_audio(voice_path, music_path, "ad_final.mp3")

print("Final file:", final)
# Out:
# Craving something delicious? Your favorite flavors are just a tap away. Fast delivery, hot and fresh, every time. From sushi to burgers, choose, track, and savor. Food on demand, mouthwatering moments, delivered to your door. Order now and taste the difference.
# Final file: d:\Projects\audio-ai-lab\outputs\final\ad_final.mp3
